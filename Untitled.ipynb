# %%
import json
import pandas as pd
import geopandas as gpd

gdf_2010 = gpd.read_file('/Users/jinglanlin/Desktop/School/01 UCLA/04 Spring 2022/UP 229 DS/Github/UDS-Project--Full-Team-/landvalue_2010_new.geojson')
#gdf_2010 = gdf_2010.rename(columns={'roll_totalvalue': 'roll_totalvalue_2010'})
#gdf_2010.set_index('ain',inplace=True)
gdf_2010
# Out:
#               ain    situszip   center_lat     center_lon rollyear  \
# 0      5076004007  90006-5707  34.05402081  -118.28692121     2010
# 1      5076004042       90006  34.05416636  -118.28739291     2010
# 2      5076004067       90006  34.05416636  -118.28739291     2010
# 3      5076004028       90006  34.05416636  -118.28739291     2010
# 4      5076004030       90006  34.05416636  -118.28739291     2010
# ...           ...         ...          ...            ...      ...
# 41149  5443034007  90039-3714  34.09879045  -118.25012427     2010
# 41150  5443034040  90039-3708  34.09793157  -118.24867157     2010
# 41151  5443030020  90039-3715  34.09685223  -118.24962420     2010
# 41152  5443035014  90039-3707  34.09866725  -118.24913765     2010
# 41153  5443030015  90039-3715  34.09689235  -118.24994122     2010
#
#       roll_landvalue sqftmain roll_impbaseyear  \
# 0             227767        0             2002
# 1              58918     1050             2010
# ...

# %%
gdf_2010.query('roll_impbaseyear == "2010"').roll_impbaseyear.count()
# Out:
# 2255

# %%
gdf_2020 = gpd.read_file('/Users/jinglanlin/Desktop/School/01 UCLA/04 Spring 2022/UP 229 DS/Github/UDS-Project--Full-Team-/landvalue_2020_new.geojson')
#gdf_2010 = gdf_2010.rename(columns={'roll_totalvalue': 'roll_totalvalue_2010'})
#gdf_2010.set_index('ain',inplace=True)
gdf_2020
# Out:
#               ain    situszip          center_lat           center_lon  \
# 0      5077020022  90005-4410  34.058407889999998  -118.28599705000001
# 1      5076005009  90006-5703  34.053493189999998  -118.28575591000001
# 2      5077020007  90005-1226         34.05802164        -118.28572719
# 3      5077022011  90005-1235  34.057444230000002        -118.28839986
# 4      5077025025  90006-1707  34.056179899999997        -118.28838583
# ...           ...         ...                 ...                  ...
# 43867  5443010026  90026-2037         34.09205034         -118.2500605
# 43868  5443019012  90026-2015  34.091191930000001        -118.24722101
# 43869  5443011020  90026-2026  34.094138010000002        -118.24830944
# 43870  5443034055  90039-3710  34.098477827096318  -118.24935084519235
# 43871  5443017016  90026-2044         34.09278338        -118.24800535
#
#       rollyear roll_landvalue sqftmain roll_impbaseyear  \
# 0         2020          78883     8178             1975
# ...

# %%
gdf_2020.query('roll_impbaseyear == "2020"').roll_impbaseyear.count()
# Out:
# 1187
