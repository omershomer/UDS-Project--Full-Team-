# %%
import json
import pandas as pd
import geopandas as gpd

gdf_2010 = gpd.read_file('/Users/jinglanlin/Desktop/School/01 UCLA/04 Spring 2022/UP 229 DS/Github/UDS-Project--Full-Team-/landvalue_2010.geojson')
gdf_2010 = gdf_2010.rename(columns={'roll_totalvalue': 'roll_totalvalue_2010'})
gdf_2010.set_index('ain',inplace=True)
gdf_2010
# Out:
#               situszip   center_lat     center_lon rollyear  \
# ain
# 5076004007  90006-5707  34.05402081  -118.28692121     2010
# 5076004042       90006  34.05416636  -118.28739291     2010
# 5076004067       90006  34.05416636  -118.28739291     2010
# 5076004028       90006  34.05416636  -118.28739291     2010
# 5076004030       90006  34.05416636  -118.28739291     2010
# ...                ...          ...            ...      ...
# 5443034007  90039-3714  34.09879045  -118.25012427     2010
# 5443034040  90039-3708  34.09793157  -118.24867157     2010
# 5443030020  90039-3715  34.09685223  -118.24962420     2010
# 5443035014  90039-3707  34.09866725  -118.24913765     2010
# 5443030015  90039-3715  34.09689235  -118.24994122     2010
#
#            roll_totalvalue_2010  \
# ain
# 5076004007               228886
# 5076004042               316201
# 5076004067               442683
# 5076004028               367397
# 5076004030               433648
# ...

# %%
gdf_2020 = gpd.read_file('/Users/jinglanlin/Desktop/School/01 UCLA/04 Spring 2022/UP 229 DS/Github/UDS-Project--Full-Team-/landvalue_2020.geojson')
gdf_2020 = gdf_2020.rename(columns={'roll_totalvalue': 'roll_totalvalue_2020'})
gdf_2020.set_index('ain',inplace=True)
gdf_2020
# Out:
#               situszip          center_lat           center_lon rollyear  \
# ain
# 5077020022  90005-4410  34.058407889999998  -118.28599705000001     2020
# 5076005009  90006-5703  34.053493189999998  -118.28575591000001     2020
# 5077020007  90005-1226         34.05802164        -118.28572719     2020
# 5077022011  90005-1235  34.057444230000002        -118.28839986     2020
# 5077025025  90006-1707  34.056179899999997        -118.28838583     2020
# ...                ...                 ...                  ...      ...
# 5443010026  90026-2037         34.09205034         -118.2500605     2020
# 5443019012  90026-2015  34.091191930000001        -118.24722101     2020
# 5443011020  90026-2026  34.094138010000002        -118.24830944     2020
# 5443034055  90039-3710  34.098477827096318  -118.24935084519235     2020
# 5443017016  90026-2044         34.09278338        -118.24800535     2020
#
#            roll_totalvalue_2020  \
# ain
# 5077020022               290785
# ...

# %%
gdf_2020.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 43872 entries, 5077020022 to 5443017016
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   situszip                   43869 non-null  object
#  1   center_lat                 43872 non-null  object
#  2   center_lon                 43872 non-null  object
#  3   rollyear                   43872 non-null  object
#  4   roll_totalvalue_2020       43872 non-null  object
#  5   location_1                 43872 non-null  object
#  6   propertylocation           43872 non-null  object
#  7   usecodedescchar1           43872 non-null  object
#  8   effectiveyearbuilt         43872 non-null  object
#  9   parcelboundarydescription  43872 non-null  object
#  10  roll_landbaseyear          43872 non-null  object
#  11   situscity                 0 non-null      object
#  12  OBJECTID_left              43872 non-null  float64
# ...

# %%
gdf_2010 = gdf_2010.drop(['index_right'],axis=1)
gdf_2020 = gdf_2020.drop(['index_right'],axis=1)

# %%
gdf_join = gdf_2020.merge(gdf_2010, how='left', on='ain')
gdf_join
# Out:
#             situszip_x        center_lat_x         center_lon_x rollyear_x  \
# ain
# 5077020022  90005-4410  34.058407889999998  -118.28599705000001       2020
# 5076005009  90006-5703  34.053493189999998  -118.28575591000001       2020
# 5077020007  90005-1226         34.05802164        -118.28572719       2020
# 5077022011  90005-1235  34.057444230000002        -118.28839986       2020
# 5077025025  90006-1707  34.056179899999997        -118.28838583       2020
# ...                ...                 ...                  ...        ...
# 5443010026  90026-2037         34.09205034         -118.2500605       2020
# 5443019012  90026-2015  34.091191930000001        -118.24722101       2020
# 5443011020  90026-2026  34.094138010000002        -118.24830944       2020
# 5443034055  90039-3710  34.098477827096318  -118.24935084519235       2020
# 5443017016  90026-2044         34.09278338        -118.24800535       2020
#
#            roll_totalvalue_2020  \
# ain
# ...

# %%
#check if the merge is correct
print(gdf_join.iloc[2])
# Out:
# situszip_x                                                            90005-1226
# center_lat_x                                                         34.05802164
# center_lon_x                                                       -118.28572719
# rollyear_x                                                                  2020
# roll_totalvalue_2020                                                      883262
# location_1_x                   {'latitude': '34.05802164', 'needs_recoding': ...
# propertylocation_x                          2755 W 8TH ST  LOS ANGELES CA  90005
# usecodedescchar1_x                                                   Residential
# effectiveyearbuilt_x                                                        1922
# parcelboundarydescription_x    BONITA VISTA TRACT # 1 EX OF ST LOT    9 BLK    1
# roll_landbaseyear_x                                                         2016
#  situscity_x                                                                None
# ...
